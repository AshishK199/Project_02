# %%
import pyspark
from pyspark import SparkContext
sc = SparkContext.getOrCreate();
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LAPTOP-F243HIRC:4046">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import pandas as pd
import tweepy

# %%
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Follower Count:{ith_tweet[1]}")
    print(f"Retweet Count:{ith_tweet[2]}")

# %%
def scrape(words, date_since, numtweet):
    db = pd.DataFrame(columns=['username','followers', 'retweetcount'])
    tweets = tweepy.Cursor(api.search, q=words, lang="en",since=date_since, tweet_mode='extended').items(numtweet)
    list_tweets = [tweet for tweet in tweets]
    i = 1  
    for tweet in list_tweets:
        username = tweet.user.screen_name
        followers = tweet.user.followers_count
        retweetcount = tweet.retweet_count
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        ith_tweet = [username,followers,retweetcount]
        db.loc[len(db)] = ith_tweet
        printtweetdata(i, ith_tweet)
        i = i+1
    filename = 'ScrapedTweets.csv'
    db.to_csv(filename)

# %%
consumer_key = 'PApQojAQOSd8iWdMdWeumD5i2'
consumer_secret = 'lUEA33FLEUK1hO52LlLnRbFulopaDYYLes5EDqnImO5XmyPqLg'
access_key = '1425317741997694976-IkA7s2zdUdQp1XdiO2YZaWDaUTSk3D'
access_secret = 'jdb2xaTL50gfiyIGx6aNMwihLe0ff0T4peX0ectErrYEy'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
words = "joebiden"
date_since = "2021-06-05"
numtweet = 100

# %%
scrape(words, date_since, numtweet)
# Out:
# Tweet 1:
# Username:JGBdeAraujo
# Follower Count:6
# Retweet Count:0
#
# Tweet 2:
# Username:kellydlowery
# Follower Count:509
# Retweet Count:0
#
# Tweet 3:
# Username:jeetendramandal
# Follower Count:84
# Retweet Count:0
#
# Tweet 4:
# Username:deplorablebeast
# Follower Count:104
# Retweet Count:6929
#
# Tweet 5:
# Username:Charlestribiz
# Follower Count:53
# Retweet Count:0
#
# Tweet 6:
# Username:mingming_chan
# Follower Count:35
# Retweet Count:3
#
# Tweet 7:
# Username:joefirestonephd
# Follower Count:2064
# Retweet Count:0
#
# Tweet 8:
# Username:KathySchultheis
# Follower Count:4543
# Retweet Count:23
#
# Tweet 9:
# Username:gandharvv1
# Follower Count:138
# Retweet Count:0
#
# Tweet 10:
# Username:kassahun_tdse
# Follower Count:162
# Retweet Count:1
#
# Tweet 11:
# Username:pilebuck6363
# Follower Count:145
# Retweet Count:167
#
# Tweet 12:
# Username:darnell_marissa
# Follower Count:261
# Retweet Count:2915
#
# Tweet 13:
# Username:metrodorian
# Follower Count:6
# Retweet Count:53
#
# Tweet 14:
# Username:kassahun_tdse
# Follower Count:162
# Retweet Count:1
#
# Tweet 15:
# Username:kcmip57
# Follower Count:108
# Retweet Count:167
#
# Tweet 16:
# Username:KRIRIS3322
# Follower Count:269
# Retweet Count:143
#
# Tweet 17:
# Username:kgmk1982
# Follower Count:43
# Retweet Count:0
#
# Tweet 18:
# Username:ArnoldWong16
# Follower Count:8
# Retweet Count:0
#
# Tweet 19:
# Username:kassahun_tdse
# Follower Count:162
# Retweet Count:1
#
# Tweet 20:
# Username:haydenAStreit
# Follower Count:379
# Retweet Count:11764
#
# Tweet 21:
# Username:wiscosrealkelso
# Follower Count:351
# Retweet Count:19
#
# Tweet 22:
# Username:kassahun_tdse
# Follower Count:162
# Retweet Count:1
#
# Tweet 23:
# Username:iMAM_MAHDi_313
# Follower Count:611
# Retweet Count:1
#
# Tweet 24:
# Username:annle
# Follower Count:248
# Retweet Count:19
#
# Tweet 25:
# Username:OfficialOsasuyi
# Follower Count:752
# Retweet Count:6929
#
# Tweet 26:
# Username:kassahun_tdse
# Follower Count:162
# Retweet Count:1
#
# Tweet 27:
# Username:UnitedS71607616
# Follower Count:51
# Retweet Count:17
#
# Tweet 28:
# Username:GianniDAngeloww
# Follower Count:524
# Retweet Count:0
#
# Tweet 29:
# Username:KauravAshutosh
# Follower Count:51
# Retweet Count:859
#
# Tweet 30:
# Username:ctrebnick
# Follower Count:2671
# Retweet Count:0
#
# Tweet 31:
# Username:daveash123
# Follower Count:186
# Retweet Count:1302
#
# Tweet 32:
# Username:kassahun_tdse
# Follower Count:162
# Retweet Count:1
#
# Tweet 33:
# Username:Notaliberal123
# Follower Count:30
# Retweet Count:1302
#
# Tweet 34:
# Username:AdkePramod
# Follower Count:20
# Retweet Count:0
#
# Tweet 35:
# Username:rust_dave
# Follower Count:348
# Retweet Count:147
#
# Tweet 36:
# Username:Alia_theQueen_
# Follower Count:72
# Retweet Count:53
#
# Tweet 37:
# Username:joefirestonephd
# Follower Count:2064
# Retweet Count:0
#
# Tweet 38:
# Username:FlaviusFX
# Follower Count:1949
# Retweet Count:1
#
# Tweet 39:
# Username:chris86593639
# Follower Count:0
# Retweet Count:0
#
# Tweet 40:
# Username:CraigMerry
# Follower Count:805
# Retweet Count:0
#
# Tweet 41:
# Username:monkey_bath25
# Follower Count:1
# Retweet Count:1
#
# Tweet 42:
# Username:JusPressPlay
# Follower Count:1443
# Retweet Count:1
#
# Tweet 43:
# Username:kassahun_tdse
# Follower Count:162
# Retweet Count:1
#
# Tweet 44:
# Username:scatepark
# Follower Count:2500
# Retweet Count:19
#
# Tweet 45:
# Username:QueenOfHeartsSF
# Follower Count:1082
# Retweet Count:0
#
# Tweet 46:
# Username:monkey_bath25
# Follower Count:1
# Retweet Count:2
#
# Tweet 47:
# Username:bmoschetti
# Follower Count:2183
# Retweet Count:0
#
# Tweet 48:
# Username:Murder_Fancier
# Follower Count:14615
# Retweet Count:0
#
# Tweet 49:
# Username:RUKUSmag
# Follower Count:3350
# Retweet Count:0
#
# Tweet 50:
# Username:ettieeden
# Follower Count:689
# Retweet Count:17
#
# Tweet 51:
# Username:Alia_theQueen_
# Follower Count:72
# Retweet Count:339
#
# Tweet 52:
# Username:LordMunoz__
# Follower Count:433
# Retweet Count:195
#
# Tweet 53:
# Username:Workinglate
# Follower Count:85
# Retweet Count:0
#
# Tweet 54:
# Username:kassahun_tdse
# Follower Count:162
# Retweet Count:1
#
# Tweet 55:
# Username:icbharadwaj
# Follower Count:30
# Retweet Count:859
#
# Tweet 56:
# Username:domisoHK
# Follower Count:107
# Retweet Count:32
#
# Tweet 57:
# Username:hale_akay
# Follower Count:18689
# Retweet Count:1
#
# Tweet 58:
# Username:WestonandJodi
# Follower Count:1908
# Retweet Count:167
#
# Tweet 59:
# Username:DK_RTM
# Follower Count:131
# Retweet Count:0
#
# Tweet 60:
# Username:gandharvv1
# Follower Count:138
# Retweet Count:0
#
# Tweet 61:
# Username:lemjen97
# Follower Count:415
# Retweet Count:0
#
# Tweet 62:
# Username:ScottTBrower1
# Follower Count:3618
# Retweet Count:0
#
# Tweet 63:
# Username:WareTruth
# Follower Count:1833
# Retweet Count:6929
#
# Tweet 64:
# Username:godi_media25
# Follower Count:1
# Retweet Count:2
#
# Tweet 65:
# Username:Abe_Tuwaijri
# Follower Count:525
# Retweet Count:11764
#
# Tweet 66:
# Username:narendra_garre
# Follower Count:175
# Retweet Count:0
#
# Tweet 67:
# Username:MoJamesApted
# Follower Count:1203
# Retweet Count:19
#
# Tweet 68:
# Username:battycakes
# Follower Count:1153
# Retweet Count:19
#
# Tweet 69:
# Username:UghAshleigh
# Follower Count:332
# Retweet Count:19
#
# Tweet 70:
# Username:dillonpunjabiG
# Follower Count:967
# Retweet Count:16
#
# Tweet 71:
# Username:False_Song
# Follower Count:1250
# Retweet Count:0
#
# Tweet 72:
# Username:gfp3
# Follower Count:318
# Retweet Count:0
#
# Tweet 73:
# Username:LesMiz2020
# Follower Count:182
# Retweet Count:19
#
# Tweet 74:
# Username:ASchaper310
# Follower Count:184
# Retweet Count:0
#
# Tweet 75:
# Username:AkashKu85518211
# Follower Count:10
# Retweet Count:2303
#
# Tweet 76:
# Username:_KennyUong_
# Follower Count:5607
# Retweet Count:19
#
# Tweet 77:
# Username:jez_1985
# Follower Count:2164
# Retweet Count:2915
#
# Tweet 78:
# Username:kanimozhi
# Follower Count:43184
# Retweet Count:0
#
# Tweet 79:
# Username:Darwin1800
# Follower Count:2211
# Retweet Count:1
#
# Tweet 80:
# Username:YesWeKhan
# Follower Count:865
# Retweet Count:88
#
# Tweet 81:
# Username:imnigamanand
# Follower Count:0
# Retweet Count:6
#
# Tweet 82:
# Username:thatjamisonguy
# Follower Count:26
# Retweet Count:0
#
# Tweet 83:
# Username:narendra_garre
# Follower Count:175
# Retweet Count:0
#
# Tweet 84:
# Username:Sweetmama326
# Follower Count:4700
# Retweet Count:6929
#
# Tweet 85:
# Username:narendra_garre
# Follower Count:175
# Retweet Count:0
#
# Tweet 86:
# Username:Blackmanthinkin
# Follower Count:772
# Retweet Count:0
#
# Tweet 87:
# Username:JonahBlank
# Follower Count:5562
# Retweet Count:19
#
# Tweet 88:
# Username:chuck415
# Follower Count:1315
# Retweet Count:19
#
# Tweet 89:
# Username:Jukeboxphd
# Follower Count:124
# Retweet Count:0
#
# Tweet 90:
# Username:Francixco9
# Follower Count:215
# Retweet Count:6929
#
# Tweet 91:
# Username:impkd_25
# Follower Count:3
# Retweet Count:2
#
# Tweet 92:
# Username:TrumpPres2017
# Follower Count:2082
# Retweet Count:50
#
# Tweet 93:
# Username:polobro18
# Follower Count:22
# Retweet Count:0
#
# Tweet 94:
# Username:B8N7ON
# Follower Count:669
# Retweet Count:0
#
# Tweet 95:
# Username:mihf811
# Follower Count:50
# Retweet Count:19
#
# Tweet 96:
# Username:Panchaliduttac1
# Follower Count:212
# Retweet Count:16
#
# Tweet 97:
# Username:deansline
# Follower Count:3448
# Retweet Count:1
#
# Tweet 98:
# Username:GroupPeeman
# Follower Count:63
# Retweet Count:59
#
# Tweet 99:
# Username:shaneilahi
# Follower Count:395
# Retweet Count:1
#
# Tweet 100:
# Username:one2be4ever
# Follower Count:161
# Retweet Count:11764
