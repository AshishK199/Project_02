# %%
import pyspark
from pyspark import SparkContext
sc = SparkContext.getOrCreate();
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LAPTOP-F243HIRC:4047">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import pandas as pd
import tweepy

# %%
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Following Count:{ith_tweet[1]}")
    print(f"Follower Count:{ith_tweet[2]}")
    print(f"Total Tweets:{ith_tweet[3]}")
    print(f"Retweet Count:{ith_tweet[4]}")

# %%
def scrape(words, date_since, numtweet):
    db = pd.DataFrame(columns=['username','following','followers', 'totaltweets', 'retweetcount'])
    tweets = tweepy.Cursor(api.search, q=words, lang="en",since=date_since, tweet_mode='extended').items(numtweet)
    list_tweets = [tweet for tweet in tweets]
    i = 1  
    for tweet in list_tweets:
        username = tweet.user.screen_name
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        ith_tweet = [username,following,followers,totaltweets, retweetcount]
        db.loc[len(db)] = ith_tweet
        printtweetdata(i, ith_tweet)
        i = i+1
    filename = 'ScrapedTweets.csv'
    db.to_csv(filename)

# %%
consumer_key = 'PApQojAQOSd8iWdMdWeumD5i2'
consumer_secret = 'lUEA33FLEUK1hO52LlLnRbFulopaDYYLes5EDqnImO5XmyPqLg'
access_key = '1425317741997694976-IkA7s2zdUdQp1XdiO2YZaWDaUTSk3D'
access_secret = 'jdb2xaTL50gfiyIGx6aNMwihLe0ff0T4peX0ectErrYEy'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
words = "ELon Musk"
date_since = "2020-08-20"
numtweet = 100

# %%
scrape(words, date_since, numtweet)
# Out:
# Tweet 1:
# Username:immigrants24
# Following Count:67
# Follower Count:2763
# Total Tweets:130989
# Retweet Count:1
#
# Tweet 2:
# Username:TriteTrite
# Following Count:4991
# Follower Count:1572
# Total Tweets:68158
# Retweet Count:2
#
# Tweet 3:
# Username:JaimeArrieta
# Following Count:915
# Follower Count:602
# Total Tweets:4208
# Retweet Count:127
#
# Tweet 4:
# Username:KishanL16877382
# Following Count:333
# Follower Count:4
# Total Tweets:187
# Retweet Count:3546
#
# Tweet 5:
# Username:SpartanXay
# Following Count:379
# Follower Count:45
# Total Tweets:783
# Retweet Count:53
#
# Tweet 6:
# Username:TapanKumarSasm1
# Following Count:1515
# Follower Count:208
# Total Tweets:4926
# Retweet Count:53
#
# Tweet 7:
# Username:newsfilterio
# Following Count:181
# Follower Count:16429
# Total Tweets:796674
# Retweet Count:0
#
# Tweet 8:
# Username:Nguynin37389510
# Following Count:104
# Follower Count:13
# Total Tweets:376
# Retweet Count:20
#
# Tweet 9:
# Username:Reenath
# Following Count:156
# Follower Count:293
# Total Tweets:91014
# Retweet Count:17
#
# Tweet 10:
# Username:Mushfiq14186783
# Following Count:926
# Follower Count:23
# Total Tweets:1640
# Retweet Count:3546
#
# Tweet 11:
# Username:dailytradingapp
# Following Count:266
# Follower Count:311
# Total Tweets:34595
# Retweet Count:0
#
# Tweet 12:
# Username:RifkyRoshad
# Following Count:167
# Follower Count:4
# Total Tweets:177
# Retweet Count:3546
#
# Tweet 13:
# Username:Awaissiraj001_
# Following Count:32
# Follower Count:0
# Total Tweets:3
# Retweet Count:0
#
# Tweet 14:
# Username:go_mohan
# Following Count:1445
# Follower Count:5872
# Total Tweets:15106
# Retweet Count:0
#
# Tweet 15:
# Username:linlinzhq
# Following Count:17
# Follower Count:0
# Total Tweets:3
# Retweet Count:669
#
# Tweet 16:
# Username:OfeldtTracy
# Following Count:83
# Follower Count:41
# Total Tweets:1615
# Retweet Count:226
#
# Tweet 17:
# Username:6K8LbCurYQ4GkUO
# Following Count:2
# Follower Count:0
# Total Tweets:9
# Retweet Count:0
#
# Tweet 18:
# Username:Blackki19656304
# Following Count:1095
# Follower Count:220
# Total Tweets:2701
# Retweet Count:3546
#
# Tweet 19:
# Username:pencarirece_
# Following Count:1035
# Follower Count:60
# Total Tweets:2483
# Retweet Count:3546
#
# Tweet 20:
# Username:BelieveNStuff
# Following Count:177
# Follower Count:41
# Total Tweets:8383
# Retweet Count:3
#
# Tweet 21:
# Username:dude4192
# Following Count:1625
# Follower Count:225
# Total Tweets:26308
# Retweet Count:0
#
# Tweet 22:
# Username:DavidBo03050197
# Following Count:2633
# Follower Count:2512
# Total Tweets:41409
# Retweet Count:16
#
# Tweet 23:
# Username:HetangR
# Following Count:390
# Follower Count:296
# Total Tweets:7618
# Retweet Count:2
#
# Tweet 24:
# Username:AglowStockNews
# Following Count:78
# Follower Count:69
# Total Tweets:4187
# Retweet Count:0
#
# Tweet 25:
# Username:usuf_alom
# Following Count:1774
# Follower Count:602
# Total Tweets:1156
# Retweet Count:3546
#
# Tweet 26:
# Username:MarshaBallard20
# Following Count:402
# Follower Count:57
# Total Tweets:2528
# Retweet Count:33
#
# Tweet 27:
# Username:bluescreen1908
# Following Count:1109
# Follower Count:21
# Total Tweets:1696
# Retweet Count:199
#
# Tweet 28:
# Username:wandera_g
# Following Count:403
# Follower Count:429
# Total Tweets:3068
# Retweet Count:250
#
# Tweet 29:
# Username:RakeshK04011158
# Following Count:21
# Follower Count:0
# Total Tweets:40
# Retweet Count:20
#
# Tweet 30:
# Username:JosephHucks
# Following Count:4958
# Follower Count:4527
# Total Tweets:97481
# Retweet Count:0
#
# Tweet 31:
# Username:Dombes12
# Following Count:388
# Follower Count:8
# Total Tweets:747
# Retweet Count:3546
#
# Tweet 32:
# Username:neer_varshney
# Following Count:287
# Follower Count:543
# Total Tweets:547
# Retweet Count:2
#
# Tweet 33:
# Username:Petros75172962
# Following Count:344
# Follower Count:126
# Total Tweets:378
# Retweet Count:250
#
# Tweet 34:
# Username:Bryanry31905446
# Following Count:406
# Follower Count:183
# Total Tweets:21853
# Retweet Count:250
#
# Tweet 35:
# Username:MrsVipPat
# Following Count:1349
# Follower Count:2745
# Total Tweets:42902
# Retweet Count:5
#
# Tweet 36:
# Username:AdrianTheCalm
# Following Count:488
# Follower Count:23
# Total Tweets:898
# Retweet Count:669
#
# Tweet 37:
# Username:RSKA45_
# Following Count:1
# Follower Count:0
# Total Tweets:4
# Retweet Count:3546
#
# Tweet 38:
# Username:DuncanGray
# Following Count:2543
# Follower Count:57264
# Total Tweets:14655
# Retweet Count:12
#
# Tweet 39:
# Username:ffsDoIo
# Following Count:783
# Follower Count:1516
# Total Tweets:29610
# Retweet Count:250
#
# Tweet 40:
# Username:dBtmuwB
# Following Count:71
# Follower Count:25
# Total Tweets:1033
# Retweet Count:0
#
# Tweet 41:
# Username:Benzinga
# Following Count:1474
# Follower Count:186650
# Total Tweets:167006
# Retweet Count:2
#
# Tweet 42:
# Username:__cryptoindia__
# Following Count:24
# Follower Count:10
# Total Tweets:4
# Retweet Count:669
#
# Tweet 43:
# Username:WMSTPSNDFLU
# Following Count:2111
# Follower Count:210
# Total Tweets:1547
# Retweet Count:1
#
# Tweet 44:
# Username:SoKo_xV
# Following Count:59
# Follower Count:79
# Total Tweets:968
# Retweet Count:156
#
# Tweet 45:
# Username:RenInSpace_
# Following Count:111
# Follower Count:10
# Total Tweets:9
# Retweet Count:1
#
# Tweet 46:
# Username:MEHEDI11100
# Following Count:487
# Follower Count:35
# Total Tweets:933
# Retweet Count:3546
#
# Tweet 47:
# Username:DevLadpura
# Following Count:2025
# Follower Count:33703
# Total Tweets:70834
# Retweet Count:0
#
# Tweet 48:
# Username:beei44683617
# Following Count:63
# Follower Count:2
# Total Tweets:130
# Retweet Count:199
#
# Tweet 49:
# Username:Deepak48078611
# Following Count:53
# Follower Count:9
# Total Tweets:1564
# Retweet Count:250
#
# Tweet 50:
# Username:BusetbudiSetia1
# Following Count:13
# Follower Count:3
# Total Tweets:244
# Retweet Count:20
#
# Tweet 51:
# Username:Eka_FOOF_A
# Following Count:1733
# Follower Count:516
# Total Tweets:28983
# Retweet Count:0
#
# Tweet 52:
# Username:3d76bce08c634e1
# Following Count:66
# Follower Count:13
# Total Tweets:71
# Retweet Count:3546
#
# Tweet 53:
# Username:SinghVishu4
# Following Count:45
# Follower Count:12
# Total Tweets:780
# Retweet Count:2
#
# Tweet 54:
# Username:dotcomhunters
# Following Count:846
# Follower Count:403
# Total Tweets:11460
# Retweet Count:0
#
# Tweet 55:
# Username:lildoge18
# Following Count:2281
# Follower Count:895
# Total Tweets:3946
# Retweet Count:12
#
# Tweet 56:
# Username:RobertFranzes11
# Following Count:161
# Follower Count:96
# Total Tweets:279
# Retweet Count:0
#
# Tweet 57:
# Username:sunnysero
# Following Count:2111
# Follower Count:2041
# Total Tweets:20863
# Retweet Count:2
#
# Tweet 58:
# Username:vidadithya
# Following Count:926
# Follower Count:967
# Total Tweets:34981
# Retweet Count:12
#
# Tweet 59:
# Username:QNET_India
# Following Count:184
# Follower Count:11877
# Total Tweets:1478
# Retweet Count:2
#
# Tweet 60:
# Username:RickyC21338477
# Following Count:169
# Follower Count:60
# Total Tweets:1206
# Retweet Count:127
#
# Tweet 61:
# Username:newts2007
# Following Count:466
# Follower Count:190
# Total Tweets:1391
# Retweet Count:101
#
# Tweet 62:
# Username:meg_gregs_ex
# Following Count:1414
# Follower Count:929
# Total Tweets:565
# Retweet Count:12
#
# Tweet 63:
# Username:DogeAccept
# Following Count:5002
# Follower Count:3903
# Total Tweets:12021
# Retweet Count:12
#
# Tweet 64:
# Username:spazzle_
# Following Count:3578
# Follower Count:2196
# Total Tweets:190649
# Retweet Count:9
#
# Tweet 65:
# Username:Anand_kani91
# Following Count:303
# Follower Count:15
# Total Tweets:558
# Retweet Count:250
#
# Tweet 66:
# Username:NijumRatri8
# Following Count:1418
# Follower Count:100
# Total Tweets:2602
# Retweet Count:3546
#
# Tweet 67:
# Username:myaiexpert1
# Following Count:446
# Follower Count:446
# Total Tweets:29604
# Retweet Count:0
#
# Tweet 68:
# Username:zahiruddin
# Following Count:1973
# Follower Count:561
# Total Tweets:13296
# Retweet Count:1
#
# Tweet 69:
# Username:hleown
# Following Count:165
# Follower Count:46
# Total Tweets:5907
# Retweet Count:2536
#
# Tweet 70:
# Username:ChelseaRhode
# Following Count:1459
# Follower Count:1221
# Total Tweets:7188
# Retweet Count:17
#
# Tweet 71:
# Username:VIKBataille
# Following Count:3172
# Follower Count:1164
# Total Tweets:305785
# Retweet Count:2
#
# Tweet 72:
# Username:AdityaGoraksha2
# Following Count:355
# Follower Count:117
# Total Tweets:39471
# Retweet Count:2
#
# Tweet 73:
# Username:Rakibul26017655
# Following Count:111
# Follower Count:3
# Total Tweets:151
# Retweet Count:3546
#
# Tweet 74:
# Username:MelaynaLokosky
# Following Count:2960
# Follower Count:5155
# Total Tweets:99476
# Retweet Count:0
#
# Tweet 75:
# Username:SovanKu32089409
# Following Count:349
# Follower Count:63
# Total Tweets:272
# Retweet Count:3546
#
# Tweet 76:
# Username:BotOfDogecoin
# Following Count:13
# Follower Count:58227
# Total Tweets:257360
# Retweet Count:12
#
# Tweet 77:
# Username:FernandSuarez01
# Following Count:133
# Follower Count:62
# Total Tweets:1445
# Retweet Count:0
#
# Tweet 78:
# Username:anand_market
# Following Count:4
# Follower Count:7
# Total Tweets:31738
# Retweet Count:0
#
# Tweet 79:
# Username:davidandrews808
# Following Count:346
# Follower Count:67
# Total Tweets:1926
# Retweet Count:0
#
# Tweet 80:
# Username:wambua_milka
# Following Count:885
# Follower Count:123
# Total Tweets:559
# Retweet Count:250
#
# Tweet 81:
# Username:ReformerNews1
# Following Count:2
# Follower Count:11
# Total Tweets:34922
# Retweet Count:0
#
# Tweet 82:
# Username:ElonAnnounces
# Following Count:1
# Follower Count:111
# Total Tweets:33856
# Retweet Count:0
#
# Tweet 83:
# Username:GuardHydro
# Following Count:578
# Follower Count:29
# Total Tweets:83
# Retweet Count:12
#
# Tweet 84:
# Username:NarutoRarri
# Following Count:33
# Follower Count:31
# Total Tweets:375
# Retweet Count:232
#
# Tweet 85:
# Username:PURELYHL
# Following Count:206
# Follower Count:25
# Total Tweets:267
# Retweet Count:250
#
# Tweet 86:
# Username:Gadgets360
# Following Count:12
# Follower Count:354247
# Total Tweets:159489
# Retweet Count:2
#
# Tweet 87:
# Username:veeborden
# Following Count:480
# Follower Count:610
# Total Tweets:55925
# Retweet Count:9
#
# Tweet 88:
# Username:ModokShonchita
# Following Count:727
# Follower Count:28
# Total Tweets:1348
# Retweet Count:3546
#
# Tweet 89:
# Username:SethPickard04
# Following Count:689
# Follower Count:173
# Total Tweets:4536
# Retweet Count:1
#
# Tweet 90:
# Username:Pratyus29523438
# Following Count:27
# Follower Count:4
# Total Tweets:1049
# Retweet Count:0
#
# Tweet 91:
# Username:Ashikuj86111562
# Following Count:164
# Follower Count:3
# Total Tweets:236
# Retweet Count:3546
#
# Tweet 92:
# Username:lolit333
# Following Count:45
# Follower Count:8
# Total Tweets:1355
# Retweet Count:51
#
# Tweet 93:
# Username:JoeSalazar17
# Following Count:2
# Follower Count:34
# Total Tweets:14899
# Retweet Count:0
#
# Tweet 94:
# Username:MRHBV310199
# Following Count:4277
# Follower Count:6118
# Total Tweets:120237
# Retweet Count:24
#
# Tweet 95:
# Username:xlCOSMOSlx
# Following Count:1338
# Follower Count:39
# Total Tweets:1407
# Retweet Count:7
#
# Tweet 96:
# Username:abworldnews
# Following Count:1
# Follower Count:632
# Total Tweets:8084
# Retweet Count:0
#
# Tweet 97:
# Username:ImEnamoured
# Following Count:1519
# Follower Count:2351
# Total Tweets:40656
# Retweet Count:24
#
# Tweet 98:
# Username:brucemiller805
# Following Count:988
# Follower Count:1741
# Total Tweets:17776
# Retweet Count:1
#
# Tweet 99:
# Username:Sabbirsr15
# Following Count:112
# Follower Count:0
# Total Tweets:195
# Retweet Count:3546
#
# Tweet 100:
# Username:1969kervin
# Following Count:441
# Follower Count:149
# Total Tweets:2295
# Retweet Count:156
